# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Aug 31 12:18:32 2022

@author: ramizouari
"""
import tensorflow as tf
import larq as lq
import numpy as np
import pandas as pd
import seaborn as sns
from binaryflow import quantizers
from binaryflow.layers import ABCNet,XnorNet,BinaryNet
from binaryflow.block import BiRealNet
from binaryflow.layers.normalization import *
from contextlib import redirect_stdout
import json
import matplotlib.pyplot as plt


data_format="channels_last"
    
(X_train,y_train),(X_test,y_test)=tf.keras.datasets.mnist.load_data()
X_train=X_train.astype(dtype=np.float32)
y_train=tf.one_hot(y_train,10)
X_test=X_test.astype(dtype=np.float32)
X_train=X_train.reshape([*X_train.shape,1])
X_test=X_test.reshape([*X_test.shape,1])
# All quantized layers except the first will use the same options

abc_args = dict(
              kernel_quantizers=quantizers.ShiftedSteSign,
              input_quantizers=quantizers.ShiftedSteSign,
                kernel_estimators=5,
              kernel_constraint="weight_clip",
              kernel_params={"mu_initializer":tf.keras.initializers.RandomNormal(0,0.05)},
              use_bias=False
              )

bnn_args=dict(kernel_quantizer="ste_sign",
              input_quantizer="ste_sign",
              kernel_constraint="weight_clip",
              use_bias=False)

Args=[bnn_args]*2+[abc_args]

Archs=[BinaryNet.QuantDense,XnorNet.ScaledQuantDense,ABCNet.ABCDense]
Names=["BinaryNet","XnorNet","ABCNet"]



Dense=BiRealNet.BiRealDense
Conv2D=XnorNet.ScaledQuantPlusConv2D



models=[]

x=tf.keras.layers.Input(shape=(28,28))
a=tf.keras.layers.GaussianNoise(stddev=4)(x)
a=ImageNormalizationLayer()(a)
#tf.keras.layers.BatchNormalization(momentum=0.999,scale=False),

#Conv2D(100,kernel=(3,3),mode=2,**bnn_args,activation="relu"),
a=tf.keras.layers.Flatten()(a)
a=tf.keras.layers.BatchNormalization(momentum=0.999,scale=False)(a)

a=BinaryNet.Dense(1024,activation="relu",**bnn_args)(a)
a=tf.keras.layers.BatchNormalization(momentum=0.999,scale=False)
a=BinaryNet.Dense(1024,**bnn_args)(x)
tf.keras.layers.BatchNormalization(momentum=0.999,scale=False)(a)
tf.keras.layers.Dense(10)(a)
y=tf.keras.layers.Activation("softmax")(a)
model=tf.keras.Model(x,y)

models.append(model)
model.compile(
tf.keras.optimizers.Adam(lr=0.01, decay=0.0001),
loss="categorical_crossentropy",
metrics=["accuracy"],
)
model.run_eagerly=True

trained_model = model.fit(
    X_train, 
    y_train,
    batch_size=128, 
    epochs=1,
    validation_data=(X_test, tf.one_hot(y_test, 10)),
    shuffle=True
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_104124/3882465986.py in <cell line: 69>()
#      67 a=tf.keras.layers.BatchNormalization(momentum=0.999,scale=False)(a)
#      68
# ---> 69 a=BinaryNet.Dense(1024,activation="relu",**bnn_args)(a)
#      70 a=tf.keras.layers.BatchNormalization(momentum=0.999,scale=False)
#      71 a=BinaryNet.Dense(1024,**bnn_args)(x)
#
# ~/anaconda3/envs/tensorflow_2_9/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/Academic/AI/QNN/Implementation/BNN/notebooks/binaryflow/layers/BinaryNet.py in tf__call(self, input, is_training, **kwargs)
#      11                 try:
#      12                     do_return = True
# ---> 13                     retval_ = ag__.converted_call(ag__.ld(tensorflow).cond, (ag__.ld(self).deployed, ag__.autograph_artifact(lambda : ag__.converted_call(ag__.ld(deploy).binarized_batch_mat_mul_tensor, (ag__.ld(self).binarized_kernel, ag__.ld(input)), dict(transpose=False), fscope)), ag__.autograph_artifact(lambda : ag__.converted_call(ag__.converted_call(ag__.ld(super), (ag__.ld(Dense), ag__.ld(self)), None, fscope).call, (ag__.ld(input),), None, fscope))), None, fscope)
#      14                 except:
#      15                     do_return = False
#
# ~/Academic/AI/QNN/Implementation/BNN/notebooks/binaryflow/layers/BinaryNet.py in <lambda>()
#      11                 try:
#      12                     do_return = True
# ---> 13                     retval_ = ag__.converted_call(ag__.ld(tensorflow).cond, (ag__.ld(self).deployed, ag__.autograph_artifact(lambda : ag__.converted_call(ag__.ld(deploy).binarized_batch_mat_mul_tensor, (ag__.ld(self).binarized_kernel, ag__.ld(input)), dict(transpose=False), fscope)), ag__.autograph_artifact(lambda : ag__.converted_call(ag__.converted_call(ag__.ld(super), (ag__.ld(Dense), ag__.ld(self)), None, fscope).call, (ag__.ld(input),), None, fscope))), None, fscope)
#      14                 except:
#      15                     do_return = False
#
# ~/Academic/AI/QNN/Implementation/BNN/notebooks/binaryflow/deploy.py in tf__binarized_batch_mat_mul_tensor(A, U, padding, transpose)
#      46                 try:
#      47                     do_return = True
# ---> 48                     retval_ = ag__.converted_call(ag__.ld(tf).bitwise.left_shift, (ag__.converted_call(ag__.ld(tf).cast, (ag__.ld(X), ag__.ld(tf).int32), None, fscope), 1), None, fscope) - (ag__.ld(n) << 6) - ag__.ld(r)
#      49                 except:
#      50                     do_return = False
#
# TypeError: Exception encountered when calling layer "dense_1" (type Dense).
#
# in user code:
#
#     File "/home/ramizouari/Academic/AI/QNN/Implementation/BNN/notebooks/binaryflow/layers/BinaryNet.py", line 36, in call  *
#         lambda :super(Dense,self).call(input))
#     File "/home/ramizouari/Academic/AI/QNN/Implementation/BNN/notebooks/binaryflow/deploy.py", line 137, in binarized_batch_mat_mul_tensor  *
#         return tf.bitwise.left_shift(tf.cast(X,tf.int32),1) - (n<<6) - r
#
#     TypeError: Input 'y' of 'Sub' Op has type int64 that does not match type int32 of argument 'x'.
#
#
# Call arguments received by layer "dense_1" (type Dense):
#   • input=tf.Tensor(shape=(None, 784), dtype=float32)
#   • is_training=False
#   • kwargs={'training': 'False'}
